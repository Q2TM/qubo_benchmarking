# %%
from graph import *

# %%
m = generate_random_symmetric_matrix(8, 1, 9)
labels = [str(i) for i in range(8)]

draw_graph("Full Dense Matrix", labels, [m], ["d"])

# %%
m_50 = make_sparse(m, 0.5)

draw_graph("Dense 50%", labels, [m], ["d"])

# %%
m_10 = make_sparse(m, 0.1)

draw_graph("Dense 10%", labels, [m], ["d"])

# %%
m = generate_random_symmetric_matrix(8, 1, 90, seed=123)
labels = [str(i) for i in range(8)]

draw_graph("Full Dense Matrix", labels, [m], ["d"])

print(*[row for row in m], sep="\n")
# Out:
# [ 0 61 53  5 81 20 23 17]
# [61  0 31 73 41 83 41 25]
# [53 31  0 80  3 46 24 22]
# [ 5 73 80  0 37 66 14 57]
# [81 41  3 37  0 72 19 47]
# [20 83 46 66 72  0  2 52]
# [23 41 24 14 19  2  0 65]
# [17 25 22 57 47 52 65  0]
